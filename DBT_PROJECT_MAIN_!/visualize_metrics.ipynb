# %%
import pandas as pd

df = pd.read_csv("performance_comparison.csv")
print("Columns:", df.columns.tolist())
print(df.head())
# Out:
# Columns: ['Streaming', '2025-04-05 17:16:24', '2.46', '0.00', '69.02']
#    Streaming  2025-04-05 17:16:24  2.46  0.00  69.02
# 0  Streaming  2025-04-05 17:16:28  2.49   0.0  69.02
# 1  Streaming  2025-04-05 17:16:31  1.92   1.0  69.02
# 2  Streaming  2025-04-05 17:16:34  1.91   0.0  69.02
# 3  Streaming  2025-04-05 17:16:37  2.39   0.0  69.02
# 4  Streaming  2025-04-05 17:16:41  2.42   0.0  69.34

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV
df = pd.read_csv("performance_comparison.csv")

# Convert timestamp to datetime
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# Convert numeric columns
df["Execution_Time"] = pd.to_numeric(df["Execution_Time"])
df["CPU_Usage"] = pd.to_numeric(df["CPU_Usage"])
df["Memory_Usage"] = pd.to_numeric(df["Memory_Usage"])

# Plot Execution Time
plt.figure(figsize=(12, 6))
for batch_type in df["Batch_Type"].unique():
    sub = df[df["Batch_Type"] == batch_type]
    plt.plot(sub["Timestamp"], sub["Execution_Time"], label=batch_type)

plt.xlabel("Timestamp")
plt.ylabel("Execution Time (s)")
plt.title("Execution Time over Time")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot CPU Usage
plt.figure(figsize=(12, 6))
for batch_type in df["Batch_Type"].unique():
    sub = df[df["Batch_Type"] == batch_type]
    plt.plot(sub["Timestamp"], sub["CPU_Usage"], label=batch_type)

plt.xlabel("Timestamp")
plt.ylabel("CPU Usage (%)")
plt.title("CPU Usage over Time")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Plot Memory Usage
plt.figure(figsize=(12, 6))
for batch_type in df["Batch_Type"].unique():
    sub = df[df["Batch_Type"] == batch_type]
    plt.plot(sub["Timestamp"], sub["Memory_Usage"], label=batch_type)

plt.xlabel("Timestamp")
plt.ylabel("Memory Usage (MB)")
plt.title("Memory Usage over Time")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
